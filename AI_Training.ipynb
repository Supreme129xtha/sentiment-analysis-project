# %% [markdown]
# <a href="https://colab.research.google.com/github/Supreme129xtha/sentiment-analysis-project/blob/main/AI_Training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install (Colab usually has these, but just in case)
# !pip install numpy pandas tensorflow scikit-learn

# Import libraries
import numpy as np
import pandas as pd
import tensorflow as tf

from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
# Sample dataset
data = {
    "review": [
        "This product is amazing",
        "I love this item",
        "Absolutely fantastic experience",
        "Very bad quality",
        "I hate this product",
        "Worst purchase ever",
        "Really good and useful",
        "Not worth the money",
        "Excellent quality",
        "Terrible experience"
    ],
    "sentiment": [1,1,1,0,0,0,1,0,1,0]
}

df = pd.DataFrame(data)
df.head()
# Out:
#                             review  sentiment
# 0          This product is amazing          1
# 1                 I love this item          1
# 2  Absolutely fantastic experience          1
# 3                 Very bad quality          0
# 4              I hate this product          0

# %%
# Split data
X = df['review']
y = df['sentiment']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Tokenize text
tokenizer = Tokenizer(num_words=1000)
tokenizer.fit_on_texts(X_train)

X_train_seq = tokenizer.texts_to_sequences(X_train)
X_test_seq = tokenizer.texts_to_sequences(X_test)

# Pad sequences
max_len = 20
X_train_pad = pad_sequences(X_train_seq, maxlen=max_len)
X_test_pad = pad_sequences(X_test_seq, maxlen=max_len)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(input_dim=1000, output_dim=16, input_length=max_len),
    tf.keras.layers.LSTM(32),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.compile(
    loss='binary_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(X_train_pad, y_train, epochs=10, validation_data=(X_test_pad, y_test))
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - accuracy: 0.5000 - loss: 0.6922 - val_accuracy: 0.5000 - val_loss: 0.6925
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.7500 - loss: 0.6915 - val_accuracy: 0.5000 - val_loss: 0.6927
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.8750 - loss: 0.6907 - val_accuracy: 0.5000 - val_loss: 0.6930
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.8750 - loss: 0.6899 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.8750 - loss: 0.6891 - val_accuracy: 0.5000 - val_loss: 0.6934
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 1.0000 - loss: 0.6883 - val_accuracy: 0.5000 - val_loss: 0.6937
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 1.0000 - loss: 0.6874 - val_accuracy: 0.5000 - val_loss: 0.6939
# Epoch 8/10
# ...

# %%
loss, accuracy = model.evaluate(X_test_pad, y_test)
print("Accuracy:", accuracy)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.5000 - loss: 0.6947
# Accuracy: 0.5

# %%
def predict_sentiment(text):
    seq = tokenizer.texts_to_sequences([text])
    pad = pad_sequences(seq, maxlen=max_len)
    prediction = model.predict(pad)[0][0]

    if prediction > 0.6:
        return "Positive review 😊"
    else:
        return "Negative review 😡"

# Test
print(predict_sentiment("This product is really good"))
print(predict_sentiment("I hate this item"))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Negative review 😡
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Negative review 😡

# %%
model.save("sentiment_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from google.colab import files
files.download("sentiment_model.h5")

# %%
import pickle

with open("tokenizer.pkl", "wb") as f:
    pickle.dump(tokenizer, f)

from google.colab import files
files.download("tokenizer.pkl")
